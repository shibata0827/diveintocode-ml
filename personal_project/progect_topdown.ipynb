# %%
# カレントディレクトリの変更

import os

os.chdir('/content/')

# カレントディレクトリの取得
print(os.getcwd())
# Out:
# /content

# %%
# 自分のマイドライブにマウントする

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# ディレクトリ変更
os.chdir('./drive/My Drive/project/')
# カレントディレクトリの取得
print(os.getcwd())
# Out:
# /content/drive/My Drive/project

# %%
# !git clone https://github.com/giannislelekas/topdown
# Out:
# Cloning into 'topdown'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 53 (delta 17), reused 44 (delta 11), pack-reused 0
# Unpacking objects: 100% (53/53), done.

# %%
# ディレクトリ変更
os.chdir('./topdown/src/')
# カレントディレクトリの取得
print(os.getcwd())
# Out:
# /content/drive/My Drive/project/topdown/src

# %%
# !pwd
# Out:
# /content/drive/My Drive/project/topdown/src

# %% [markdown]
# # FMNIST の NIN_lightでBUとTD（run_BUvsTD.py）

# %%
# tensor系のインストール（requirements）
# !pip install tensorboard==1.14.0
# !pip install tensorflow==1.14.0
# !pip install tensorflow-base==1.14.0
# !pip install tensorflow-estimator==1.14.0
# !pip install tensorflow-gpu==1.14.0
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement tensorflow-base==1.14.0 (from versions: none)
# ERROR: No matching distribution found for tensorflow-base==1.14.0
# ...

# %%
# エポック(e)=3、繰り返し回数(r)=2テスト
# !python run_BUvsTD.py -d MNIST -m LeNetFC -l 0.1 -w 0 -e 3 -r 2 -b 128 -v 0.1 -s scheduler_3_stage
# できた　→　出力されたファイルは削除

# FMNIST の NIN_lightでBUとTD
# BU
# !python run_BUvsTD.py -d FMNIST -m NIN_light -l 0.1 -w 0 -e 50 -r 4 -b 128 -v 0.1 -s scheduler_3_stage
# Out:
# 2020-04-28 11:24:18.184056: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Generating folder ./../../output/models/FMNIST_S/
# Generating folder ./../../output/history/FMNIST_S/
# Generating folder ./../../output/output/FMNIST_S/
# Generating folder ./../../output/graphs/FMNIST_S/
# Executing NIN_light on dataset FMNIST_S
#
# ...
# 4423680/4422102 [==============================] - 0s 0us/step
# 2020-04-28 11:24:32.010648: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-28 11:24:32.054031: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-28 11:24:32.054858: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# ...

# %%
# TD
# !python run_BUvsTD.py -d FMNIST_S -m NIN_light_TD -l 0.1 -w 0 -e 50 -r 4 -b 128 -v 0.1 -s scheduler_3_stage
# Out:
# 2020-04-28 12:32:21.042221: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Executing NIN_light_TD on dataset FMNIST_S
#
# 2020-04-28 12:32:24.280803: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-28 12:32:24.298872: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-28 12:32:24.299632: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2020-04-28 12:32:24.299679: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...

# %% [markdown]
# # FMNIST の NIN_lightでBUとTD　→　gradcam

# %%
# FMNIST の NIN_lightでBUとTD　→　gradcam
# run_imagenette.py", line 19のscripts.run_BUvsTDをrun_BUvsTDへ変更
# BU
# !python run_gradcam.py -d FMNIST -m NIN_light -b 128 -r 4
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# run_gradcamの138行目　f'{out_path}/output → f'{out_path}output
# TD
# !python run_gradcam.py -d FMNIST -m NIN_light_TD -b 128 -r 4
# Out:
# Ind:  [9394  898 2398 ... 3264 9845 2732]
# ./../../output/models/FMNIST/NIN_light_TD_it0.h5
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2020-04-29 00:17:56.226411: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-29 00:17:56.298908: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-29 00:17:56.299571: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# ...

# %% [markdown]
# # ResNet IMAGENETTE(時間の関係でaugなし、デフォルト)
# # →　gradcam

# %%
# !pip install wget

# %%
# !pip install numpy==1.16.4
# !pip install numpy-base==1.16.4
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement numpy-base==1.16.4 (from versions: none)
# ERROR: No matching distribution found for numpy-base==1.16.4

# %%
# BU run_imagenette
# !python run_imagenette.py -d IMAGENETTE -m ResNet18 -l 0.1 -w 1e-3 -e 50 -r 1 -b 128 -s scheduler_3_stage -p True
# Out:
# ResNet18
# tcmalloc: large alloc 2765258752 bytes == 0x5c96000 @  0x7f9b4ea5c1e7 0x7f9b4afbaca1 0x7f9b4b01f778 0x7f9b4afbe4a1 0x551b15 0x5aa6ec 0x50abb3 0x50d390 0x508245 0x50a080 0x50aa7d 0x50d390 0x509455 0x595311 0x5a067e 0x557d28 0x50c88b 0x508245 0x50a080 0x50aa7d 0x50d390 0x509d48 0x50aa7d 0x50c5b9 0x508245 0x50b403 0x635222 0x6352d7 0x638a8f 0x639631 0x4b0f40
# tcmalloc: large alloc 2765258752 bytes == 0xd8b32000 @  0x7f9b4ea5c1e7 0x7f9b4afbaca1 0x7f9b4b01f778 0x7f9b4b01f893 0x7f9b4b0d4bcd 0x7f9b4b0d552e 0x7f9b4b0d7ea8 0x7f9b4b21a586 0x7f9b4b21aaf4 0x7f9b4b21e7f2 0x7f9b4b21f66e 0x5a522c 0x5a58f8 0x7f9b4b0dfe9b 0x59d282 0x50d16f 0x508245 0x50a080 0x50aa7d 0x50d390 0x508245 0x58958c 0x5a067e 0x50d966 0x508245 0x50a080 0x50aa7d 0x50d390 0x509d48 0x50aa7d 0x50c5b9
# ...

# %%
# TD run_imagenette
# !python run_imagenette.py -d IMAGENETTE -m ResNet18_TD -l 0.05 -w 1e-3 -e 50 -r 1 -b 64 -s scheduler_3_stage -p True
# Out:
# ResNet18_TD
# tcmalloc: large alloc 2765258752 bytes == 0x70b4000 @  0x7fd4f53901e7 0x7fd4f18eeca1 0x7fd4f1953778 0x7fd4f18f24a1 0x551b15 0x5aa6ec 0x50abb3 0x50d390 0x508245 0x50a080 0x50aa7d 0x50d390 0x509455 0x595311 0x5a067e 0x557d28 0x50c88b 0x508245 0x50a080 0x50aa7d 0x50d390 0x509d48 0x50aa7d 0x50c5b9 0x508245 0x50b403 0x635222 0x6352d7 0x638a8f 0x639631 0x4b0f40
# tcmalloc: large alloc 2765258752 bytes == 0xd9f50000 @  0x7fd4f53901e7 0x7fd4f18eeca1 0x7fd4f1953778 0x7fd4f1953893 0x7fd4f1a08bcd 0x7fd4f1a0952e 0x7fd4f1a0bea8 0x7fd4f1b4e586 0x7fd4f1b4eaf4 0x7fd4f1b527f2 0x7fd4f1b5366e 0x5a522c 0x5a58f8 0x7fd4f1a13e9b 0x59d282 0x50d16f 0x508245 0x50a080 0x50aa7d 0x50d390 0x508245 0x58958c 0x5a067e 0x50d966 0x508245 0x50a080 0x50aa7d 0x50d390 0x509d48 0x50aa7d 0x50c5b9
# ...

# %%
# BU run_gradcam
# !python run_gradcam.py -d IMAGENETTE -m ResNet18 -b 128 -r 1 -p True
# Out:
# Ind:  [ 582 1116 3920 ... 1653 2607 2732]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# ...

# %%
# TD run_gradcam
# !python run_gradcam.py -d IMAGENETTE -m ResNet18_TD -b 128 -r 1 -p True
# Out:
# Ind:  [ 582 1116 3920 ... 1653 2607 2732]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# ...

# %%
# 事前にrun_imagenette.pyでの学習が必要
# run_imagenetter.pyのextract_statistics　Xをxに変更
# run_gradcamとrun_imagenetteのtensorflow.python.keras.utilsをtensorflow.keras.utilsに変更
# run_gradcamのfrom scripts.を削除
# models_imagenetteの3行目をコメントアウト（multi_gpu_modelなし）
# trainの引数 `save_all_weight = True`を設定(MNISTおよびFashion-MNISTでgradcam見るには必要)
# ResNet_TD augの基本パラメータ
# (218, )232(, 258)のdivをmath.floordivに修正

# !python run_BUvsTD.py -d CIFAR10 -m ResNet_TD -l 0.1 -w 1e-4 -e 200 -r 4 -b 128 -v 0.1 -s scheduler_3_stage -p True -a True -ex aug
# →　メモリ足りず学習時間！！
